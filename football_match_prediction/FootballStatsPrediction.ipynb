# %%
# load from csv to pandas dataframe
import pandas as pd

# load data
matches_df = pd.read_csv('fbref_data.csv')
matches_df.shape
# Out:
# (1456, 27)

# %%
# converts date column to datetime
matches_df["date"] = pd.to_datetime(matches_df["date"])

# %%
matches_df["venue_code"] = matches_df["venue"].astype('category').cat.codes

# %%
matches_df["opp_code"] = matches_df["opponent"].astype('category').cat.codes

# %%
matches_df["hour"] = matches_df["time"].str.replace(':.+', '', regex=True).astype(int)

# %%
matches_df["day_code"] = matches_df["date"].dt.dayofweek

# %%
matches_df["target"] = (matches_df["result"] == "W").astype(int)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score

# useful for non-linear tendencies
rf = RandomForestClassifier(
    n_estimators=50,
    min_samples_split=10,
    random_state=1
)

predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

grouped_matches = matches_df.groupby("team")
group = grouped_matches.get_group("Manchester City")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
matches_rollings = matches_df.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
matches_rollings = matches_rollings.droplevel('team')
matches_rollings.index =  range(matches_rollings.shape[0])
# Out:
# /var/folders/r_/jvt1rv_x24zfn_hh6c6kkt8h0000gn/T/ipykernel_72583/4145705095.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rollings = matches_df.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
def make_predictions(data, predictors):
    training_data = data[data["date"] < "2023-01-01"]
    test_data = data[data["date"] > "2023-01-01"]
    rf.fit(training_data[predictors], training_data["target"])
    preds = rf.predict(test_data[predictors])
    combined = pd.DataFrame(dict(actual=test_data["target"], prediction=preds))
    precision = precision_score(test_data["target"], preds)
    return combined, precision

# %%
combined, precision = make_predictions(matches_rollings, predictors)

# %%
precision
# Out:
# 0.5033333333333333

# %%
combined = combined.merge(matches_rollings[["date", "team", "opponent", "result"]], left_index=True, right_index=True)
combined
# Out:
#       actual  prediction       date                     team         opponent  \
# 13         0           0 2023-01-03                  Arsenal    Newcastle Utd
# 14         1           1 2023-01-15                  Arsenal        Tottenham
# 15         1           0 2023-01-22                  Arsenal   Manchester Utd
# 16         0           0 2023-02-04                  Arsenal          Everton
# 17         0           0 2023-02-11                  Arsenal        Brentford
# ...      ...         ...        ...                      ...              ...
# 1382       0           1 2024-04-06  Wolverhampton Wanderers         West Ham
# 1383       0           1 2024-04-13  Wolverhampton Wanderers  Nott'ham Forest
# 1384       0           0 2024-04-20  Wolverhampton Wanderers          Arsenal
# 1385       0           1 2024-04-24  Wolverhampton Wanderers      Bournemouth
# 1386       1           0 2024-04-27  Wolverhampton Wanderers       Luton Town
#
#      result
# 13        D
# 14        W
# 15        W
# 16        L
# 17        D
# ...     ...
# 1382      L
# 1383      D
# 1384      L
# 1385      L
# 1386      W
#
# [1115 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
    "Brighton & Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd",
    "Tottenham Hotspur": "Tottenham",
    "West Ham United": "West Ham",
    "Wolverhampton Wanderers": "Wolves",
}

mapping = MissingDict(**map_values)
mapping["Brighton & Hove Albion"]
# Out:
# 'Brighton'

# %%
combined["new_team"] = combined["team"].map(mapping)
combined
# Out:
#       actual  prediction       date                     team         opponent  \
# 13         0           0 2023-01-03                  Arsenal    Newcastle Utd
# 14         1           1 2023-01-15                  Arsenal        Tottenham
# 15         1           0 2023-01-22                  Arsenal   Manchester Utd
# 16         0           0 2023-02-04                  Arsenal          Everton
# 17         0           0 2023-02-11                  Arsenal        Brentford
# ...      ...         ...        ...                      ...              ...
# 1382       0           1 2024-04-06  Wolverhampton Wanderers         West Ham
# 1383       0           1 2024-04-13  Wolverhampton Wanderers  Nott'ham Forest
# 1384       0           0 2024-04-20  Wolverhampton Wanderers          Arsenal
# 1385       0           1 2024-04-24  Wolverhampton Wanderers      Bournemouth
# 1386       1           0 2024-04-27  Wolverhampton Wanderers       Luton Town
#
#      result new_team
# 13        D  Arsenal
# 14        W  Arsenal
# 15        W  Arsenal
# 16        L  Arsenal
# 17        D  Arsenal
# ...     ...      ...
# 1382      L   Wolves
# 1383      D   Wolves
# 1384      L   Wolves
# 1385      L   Wolves
# 1386      W   Wolves
#
# [1115 rows x 7 columns]

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])
merged
# Out:
#      actual_x  prediction_x       date                   team_x  \
# 0           0             0 2023-01-03                  Arsenal
# 1           1             1 2023-01-15                  Arsenal
# 2           1             0 2023-01-22                  Arsenal
# 3           0             0 2023-02-04                  Arsenal
# 4           0             0 2023-02-11                  Arsenal
# ..        ...           ...        ...                      ...
# 959         0             1 2024-04-06  Wolverhampton Wanderers
# 960         0             1 2024-04-13  Wolverhampton Wanderers
# 961         0             0 2024-04-20  Wolverhampton Wanderers
# 962         0             1 2024-04-24  Wolverhampton Wanderers
# 963         1             0 2024-04-27  Wolverhampton Wanderers
#
#           opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0      Newcastle Utd        D    Arsenal         0             0
# 1          Tottenham        W    Arsenal         0             0
# 2     Manchester Utd        W    Arsenal         0             0
# 3            Everton        L    Arsenal         1             0
# 4          Brentford        D    Arsenal         0             0
# ..               ...      ...        ...       ...           ...
# 959         West Ham        L     Wolves         1             1
# 960  Nott'ham Forest        D     Wolves         0             1
# 961          Arsenal        L     Wolves         1             1
# 962      Bournemouth        L     Wolves         1             0
# 963       Luton Town        W     Wolves         0             1
#
#                 team_y opponent_y result_y         new_team_y
# 0     Newcastle United    Arsenal        D      Newcastle Utd
# 1    Tottenham Hotspur    Arsenal        L          Tottenham
# 2    Manchester United    Arsenal        L     Manchester Utd
# 3              Everton    Arsenal        W            Everton
# 4            Brentford    Arsenal        D          Brentford
# ..                 ...        ...      ...                ...
# 959    West Ham United     Wolves        W           West Ham
# 960  Nottingham Forest     Wolves        D  Nottingham Forest
# 961            Arsenal     Wolves        W            Arsenal
# 962        Bournemouth     Wolves        W        Bournemouth
# 963         Luton Town     Wolves        L         Luton Town
#
# [964 rows x 13 columns]

# %%
merged[(merged["prediction_x"] == 1) & (merged["prediction_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    114
# 0    113
# Name: count, dtype: int64

# %%
114 + 113

114 /227
# Out:
# 0.5022026431718062
